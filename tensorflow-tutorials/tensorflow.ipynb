# %%
import os
import tensorflow as tf

# %%
os.environ['TFF_ CPP_MIN_LOG_LEVEL'] = '2'

# %%
# Initalization of Tensors
x = tf.constant(4, shape=(1,1), dtype=tf.float32)
x = tf.constant([[1,2,3],[4,5,6]])
print(x)
# Out:
# tf.Tensor(
# [[1 2 3]
#  [4 5 6]], shape=(2, 3), dtype=int32)
